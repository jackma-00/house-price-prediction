# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/jackma-00/house-price-prediction/blob/main/experiments/1_house_price_feature_backfill.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#333;">Feature Backfill<span>

# %% [markdown]
# Installing required packages

# %%
# !pip install hopsworks[python]
# Out:
# Collecting hopsworks[python]
#   Downloading hopsworks-4.1.4-py3-none-any.whl.metadata (11 kB)
# Collecting pyhumps==1.6.1 (from hopsworks[python])
#   Downloading pyhumps-1.6.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from hopsworks[python]) (2.32.3)
# Collecting furl (from hopsworks[python])
#   Downloading furl-2.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting boto3 (from hopsworks[python])
#   Downloading boto3-1.35.85-py3-none-any.whl.metadata (6.7 kB)
# Collecting pandas<2.2.0 (from hopsworks[python])
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting pyjks (from hopsworks[python])
#   Downloading pyjks-20.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mock (from hopsworks[python])
#   Downloading mock-5.1.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting avro==1.11.3 (from hopsworks[python])
#   Downloading avro-1.11.3.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 4.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (from hopsworks[python]) (2.0.36)
# Collecting PyMySQL[rsa] (from hopsworks[python])
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from hopsworks[python]) (5.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from hopsworks[python]) (2024.10.0)
# Collecting retrying (from hopsworks[python])
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Collecting hopsworks_aiomysql==0.2.1 (from hopsworks_aiomysql[sa]==0.2.1->hopsworks[python])
#   Downloading hopsworks_aiomysql-0.2.1-py3-none-any.whl.metadata (11 kB)
# Collecting opensearch-py<=2.4.2,>=1.1.0 (from hopsworks[python])
#   Downloading opensearch_py-2.4.2-py2.py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from hopsworks[python]) (4.67.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.49.1 in /usr/local/lib/python3.10/dist-packages (from hopsworks[python]) (1.68.1)
# Requirement already satisfied: protobuf<5.0.0,>=4.25.4 in /usr/local/lib/python3.10/dist-packages (from hopsworks[python]) (4.25.5)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from hopsworks[python]) (1.26.4)
# Requirement already satisfied: pyarrow>=10.0 in /usr/local/lib/python3.10/dist-packages (from hopsworks[python]) (17.0.0)
# Collecting confluent-kafka<=2.3.0 (from hopsworks[python])
#   Downloading confluent_kafka-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting fastavro<=1.8.4,>=1.4.11 (from hopsworks[python])
#   Downloading fastavro-1.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting sqlalchemy (from hopsworks[python])
#   Downloading SQLAlchemy-2.0.29-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: urllib3>=1.26.18 in /usr/local/lib/python3.10/dist-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks[python]) (2.2.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks[python]) (1.17.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks[python]) (2.8.2)
# Requirement already satisfied: certifi>=2022.12.07 in /usr/local/lib/python3.10/dist-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks[python]) (2024.12.14)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.0->hopsworks[python]) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.0->hopsworks[python]) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->hopsworks[python]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->hopsworks[python]) (3.10)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->hopsworks[python]) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->hopsworks[python]) (3.1.1)
# Collecting botocore<1.36.0,>=1.35.85 (from boto3->hopsworks[python])
#   Downloading botocore-1.35.85-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->hopsworks[python])
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3->hopsworks[python])
#   Downloading s3transfer-0.10.4-py3-none-any.whl.metadata (1.7 kB)
# Collecting orderedmultidict>=1.0.1 (from furl->hopsworks[python])
#   Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting javaobj-py3 (from pyjks->hopsworks[python])
#   Downloading javaobj_py3-0.4.4-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyasn1>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from pyjks->hopsworks[python]) (0.6.1)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.10/dist-packages (from pyjks->hopsworks[python]) (0.4.1)
# Collecting pycryptodomex (from pyjks->hopsworks[python])
#   Downloading pycryptodomex-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting twofish (from pyjks->hopsworks[python])
#   Downloading twofish-0.3.0.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cryptography in /usr/local/lib/python3.10/dist-packages (from PyMySQL[rsa]->hopsworks[python]) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography->PyMySQL[rsa]->hopsworks[python]) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography->PyMySQL[rsa]->hopsworks[python]) (2.22)
# Downloading hopsworks_aiomysql-0.2.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 2.9 MB/s eta 0:00:00
# Downloading pyhumps-1.6.1-py3-none-any.whl (5.0 kB)
# Downloading confluent_kafka-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 49.6 MB/s eta 0:00:00
# Downloading fastavro-1.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 59.8 MB/s eta 0:00:00
# Downloading opensearch_py-2.4.2-py2.py3-none-any.whl (258 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.6/258.6 kB 18.0 MB/s eta 0:00:00
# Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 89.1 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.29-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 79.7 MB/s eta 0:00:00
# Downloading boto3-1.35.85-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 10.3 MB/s eta 0:00:00
# Downloading furl-2.1.3-py2.py3-none-any.whl (20 kB)
# Downloading hopsworks-4.1.4-py3-none-any.whl (640 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 640.3/640.3 kB 37.4 MB/s eta 0:00:00
# Downloading mock-5.1.0-py3-none-any.whl (30 kB)
# Downloading pyjks-20.0.0-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 3.0 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading botocore-1.35.85-py3-none-any.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 82.8 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl (11 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 2.9 MB/s eta 0:00:00
# Downloading s3transfer-0.10.4-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 7.0 MB/s eta 0:00:00
# Downloading javaobj_py3-0.4.4-py2.py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 4.2 MB/s eta 0:00:00
# Downloading pycryptodomex-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 61.5 MB/s eta 0:00:00
# Building wheels for collected packages: avro, twofish
#   Building wheel for avro (pyproject.toml) ... done
#   Created wheel for avro: filename=avro-1.11.3-py2.py3-none-any.whl size=123910 sha256=9815cb7b0e1f792164382e5573560efd462c344cf1ae7c90ad5dba7bd1ba5af0
#   Stored in directory: /root/.cache/pip/wheels/1d/f6/41/0e0399396af07060e64d4e32c8bd259b48b98a4a114df31294
#   Building wheel for twofish (setup.py) ... done
#   Created wheel for twofish: filename=twofish-0.3.0-cp310-cp310-linux_x86_64.whl size=24197 sha256=1b412a8aeed10e0ee71b4859c5c4f37fdc71840772cdbe5b6f3e19c18580ae63
#   Stored in directory: /root/.cache/pip/wheels/a7/3c/27/c390be4f3e8a299d4b2836f8daa19697eb991eacbfabe25031
# Successfully built avro twofish
# Installing collected packages: twofish, pyhumps, javaobj-py3, confluent-kafka, sqlalchemy, retrying, PyMySQL, pycryptodomex, orderedmultidict, mock, jmespath, fastavro, avro, pyjks, pandas, opensearch-py, hopsworks_aiomysql, furl, botocore, s3transfer, boto3, hopsworks
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# mizani 0.13.1 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# plotnine 0.14.4 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# Successfully installed PyMySQL-1.1.1 avro-1.11.3 boto3-1.35.85 botocore-1.35.85 confluent-kafka-2.3.0 fastavro-1.8.4 furl-2.1.3 hopsworks-4.1.4 hopsworks_aiomysql-0.2.1 javaobj-py3-0.4.4 jmespath-1.0.1 mock-5.1.0 opensearch-py-2.4.2 orderedmultidict-1.0.1 pandas-2.1.4 pycryptodomex-3.21.0 pyhumps-1.6.1 pyjks-20.0.0 retrying-1.3.4 s3transfer-0.10.4 sqlalchemy-2.0.29 twofish-0.3.0

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import hopsworks
import os

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### <span style='color:#ff5f27'> Connect to Hopsworks Feature Store

# %%
# If you haven't set the env variable 'HOPSWORKS_API_KEY', then uncomment the next line and enter your API key
os.environ["HOPSWORKS_API_KEY"] = ""
proj = hopsworks.login()
# Out:
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1158295

# %% [markdown]
# ## <span style="color:#ff5f27;"> 💽 Loading the Data </span>

# %%
# Connect to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# unzip properties.zip
# !unzip /content/drive/MyDrive/properties.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/properties.zip
#   inflating: /content/properties.csv

# %%
# unzip omi.zip
# !unzip /content/drive/MyDrive/omi.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/omi.zip
#   inflating: /content/omi.csv

# %%
# Load properties CSV into Dataframe
properties_csv = 'properties.csv'
properties_df = pd.read_csv(properties_csv)

# %%
# Load omi CSV into Dataframe
omi_csv = 'omi.csv'
omi_df = pd.read_csv(omi_csv)

# %%
properties_df
# Out:
#                 id  typologyId  categoryCode   codcom  agencyId   latitude  \
# 0        109230993          14             1   1272.0       NaN  45.082779
# 1        108895067          14             1   1272.0  178139.0  45.083300
# 2        109784457          14             1   1272.0       NaN  45.058979
# 3        108547953          14             1   1272.0  392458.0  45.057200
# 4        109914147          14             1  23059.0  229787.0  45.449700
# ...            ...         ...           ...      ...       ...        ...
# 1211904  110000113          17             1   1272.0   74278.0  45.090100
# 1211905  109942307          14             1   1272.0       NaN  45.092331
# 1211906  108302933          14             1   1272.0       NaN  45.091194
# 1211907  110019089          14             1  48017.0  247117.0  43.766900
# 1211908  110297799          14             1  15159.0    1173.0  45.378000
#
#          longitude id_zona_omi                 city  \
# 0         7.644110     L219-D8               Torino
# 1         7.645500     L219-D8               Torino
# 2         7.683780     L219-B8               Torino
# 3         7.678300     L219-B8               Torino
# 4        10.668200     G489-B2  Peschiera del Garda
# ...            ...         ...                  ...
# 1211904   7.698500    L219-C10               Torino
# 1211905   7.699990    L219-D12               Torino
# 1211906   7.696717    L219-C10               Torino
# 1211907  11.251600     D612-B5              Firenze
# 1211908   9.225000     G078-D1                Opera
#
#                                            zona  ...     GA4Heating  \
# 0                         Pozzo Strada, Parella  ...  Centralizzato
# 1                         Pozzo Strada, Parella  ...  Centralizzato
# 2                                  San Salvario  ...  Centralizzato
# 3                                  San Salvario  ...       Autonomo
# 4                                        Centro  ...       Autonomo
# ...                                         ...  ...            ...
# 1211904  Aurora, Barriera di Milano, Rebaudengo  ...       Autonomo
# 1211905  Aurora, Barriera di Milano, Rebaudengo  ...  Centralizzato
# 1211906  Aurora, Barriera di Milano, Rebaudengo  ...       Autonomo
# 1211907                                Oltrarno  ...       Autonomo
# 1211908                                  Centro  ...       Autonomo
#
#         hasElevator  isNew  isLuxury  \
# 0               NaN   True     False
# 1               NaN  False     False
# 2               NaN   True     False
# 3               NaN  False     False
# 4               NaN   True     False
# ...             ...    ...       ...
# 1211904         NaN   True     False
# 1211905         NaN   True     False
# 1211906         NaN  False     False
# 1211907         NaN   True     False
# 1211908         NaN  False     False
#
#                                                description  \
# 0        Bilocale pronto da abitare situato a 5 minuti ...
# 1        ZONA CAMPIDOGLIO - VIA MICHELE LESSONA - In pi...
# 2        Piazza madama, a 5 minuti dal Parco del Valent...
# 3        MONOLOCALE IN AFFITTO ARREDATO\nRISCALDAMENTO ...
# 4        Per informazioni ELENA 393/8205511\nIn zona Sa...
# ...                                                    ...
# 1211904  In via Saverio Mercadante   affittiamo partico...
# 1211905  Alloggio in buone condizioni, abitabile, espos...
# 1211906  Privato affitta trilocale di 65 mq , zona Barr...
# 1211907  This wonderful 1BR apartment is in a fantastic...
# 1211908  Quartiere Zerbo. In piccola palazzina bilocale...
#
#                                                     photos scraping_date  \
# 0        [{'id': 1471294881, 'caption': '', 'urls': {'s...    2024-03-18
# 1        [{'id': 1465033121, 'caption': 'facciata', 'ur...    2024-03-18
# 2        [{'id': 1481631325, 'caption': '', 'urls': {'s...    2024-03-18
# 3        [{'id': 1458345959, 'caption': '', 'urls': {'s...    2024-03-18
# 4        [{'id': 1484040585, 'caption': '', 'urls': {'s...    2024-03-25
# ...                                                    ...           ...
# 1211904  [{'id': 1485646521, 'caption': 'cortile', 'url...    2024-03-18
# 1211905  [{'id': 1484556023, 'caption': '', 'urls': {'s...    2024-03-18
# 1211906  [{'id': 1452992687, 'caption': '', 'urls': {'s...    2024-03-18
# 1211907  [{'id': 1486030391, 'caption': 'Interno 1', 'u...    2024-03-15
# 1211908  [{'id': 1491502841, 'caption': 'cucina', 'urls...    2024-03-25
#
#             createdAt     updatedAt  categoryName
# 0        1.707222e+09  1.709585e+09           NaN
# 1        1.706099e+09  1.709984e+09           NaN
# 2        1.709151e+09  1.710337e+09           NaN
# 3        1.704902e+09  1.710408e+09           NaN
# 4        1.709641e+09  1.709642e+09           NaN
# ...               ...           ...           ...
# 1211904  1.709894e+09  1.709895e+09           NaN
# 1211905  1.709718e+09  1.710158e+09           NaN
# 1211906  1.703504e+09  1.704724e+09           NaN
# 1211907  1.709841e+09  1.710492e+09           NaN
# 1211908  1.630550e+09  1.710951e+09           NaN
#
# [1211909 rows x 44 columns]

# %%
omi_df

# %% [markdown]
# ## <span style="color:#ff5f27;"> Data Cleaning

# %%
properties_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1211909 entries, 0 to 1211908
# Data columns (total 44 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   id                   1211909 non-null  int64
#  1   typologyId           1211909 non-null  int64
#  2   categoryCode         1211909 non-null  int64
#  3   codcom               1209642 non-null  float64
#  4   agencyId             1110765 non-null  float64
#  5   latitude             1211909 non-null  float64
#  6   longitude            1211909 non-null  float64
#  7   id_zona_omi          1206438 non-null  object
#  8   city                 1211710 non-null  object
#  9   zona                 915626 non-null   object
#  10  quartiere            438259 non-null   object
#  11  name                 1211909 non-null  object
#  12  contract             1211909 non-null  object
#  13  surface              1211909 non-null  int64
#  14  condition            1120461 non-null  object
#  15  buildingYear         770736 non-null   float64
#  16  energyClass          912775 non-null   object
#  17  on_the_market        1211909 non-null  bool
#  18  GSM                  1198626 non-null  float64
#  19  price                1211909 non-null  float64
#  20  priceRange           1210286 non-null  object
#  21  rooms                1177055 non-null  object
#  22  bathrooms            1172575 non-null  object
#  23  garage               657728 non-null   object
#  24  floor                707005 non-null   object
#  25  floors               1025941 non-null  object
#  26  zeroEnergyBuilding   1111002 non-null  object
#  27  heatingType          1036626 non-null  object
#  28  airConditioning      432989 non-null   object
#  29  features             1067176 non-null  object
#  30  bedRoomsNumber       1055057 non-null  float64
#  31  roomsValue           1171829 non-null  object
#  32  surfaceConstitution  912393 non-null   object
#  33  propertyCosts        913551 non-null   object
#  34  GA4Heating           976954 non-null   object
#  35  hasElevator          859696 non-null   object
#  36  isNew                1211909 non-null  bool
#  37  isLuxury             1211909 non-null  bool
#  38  description          1210630 non-null  object
#  39  photos               1211909 non-null  object
#  40  scraping_date        1211909 non-null  object
#  41  createdAt            1198664 non-null  float64
#  42  updatedAt            1198664 non-null  float64
#  43  categoryName         514341 non-null   object
# dtypes: bool(3), float64(10), int64(4), object(27)
# memory usage: 382.6+ MB

# %%
omi_df.info()

# %% [markdown]
# Drop null values

# %%
properties_df.dropna(inplace=True)

# %%
omi_df.dropna(inplace=True)

# %% [markdown]
# Convert column names to lowercase

# %%
# Convert column names to lowercase
properties_df.columns = properties_df.columns.str.lower()

# %%
# Convert column names to lowercase
omi_df.columns = omi_df.columns.str.lower()

# %% [markdown]
# **Evaluating candidate features for properties fg**
#
# Primary key:
# * id
#
# Timestamp:
# * scraping_date
#
# Numerical features:
# * agencyid
# * bedroomsnumber
# * buildingyear
# * codcom
# * gsm
# * surface
# * latitude
# * longitude
#
# Boolean features:
# * isluxury
# * isnew
# * on_the_market
# * zeroenergybuilding
#
# Categorical features:
# * airconditioning
# * bathrooms
# * city
# * condition
# * energyclass
# * ga4heating
# * garage
# * heatingtype
# * pricerange
# * rooms
# * id_zona_omi
#
# Label:
# * price

# %%
# properties selected columns
properties_df = properties_df[[
    'id',
    'scraping_date',
    'agencyid',
    'bedroomsnumber',
    'buildingyear',
    'codcom',
    'gsm',
    'surface',
    'latitude',
    'longitude',
    'isluxury',
    'isnew',
    'on_the_market',
    'zeroenergybuilding',
    'airconditioning',
    'bathrooms',
    'city',
    'condition',
    'energyclass',
    'ga4heating',
    'garage',
    'heatingtype',
    'pricerange',
    'rooms',
    'id_zona_omi',
    'price',
]]

# %%
# Convert boolean features to int
properties_df['isluxury'] = properties_df['isluxury'].astype(int)
properties_df['isnew'] = properties_df['isnew'].astype(int)
properties_df['on_the_market'] = properties_df['on_the_market'].astype(int)
properties_df['zeroenergybuilding'] = properties_df['zeroenergybuilding'].astype(int)

# %%
properties_df['scraping_date'] = pd.to_datetime(properties_df['scraping_date'])
properties_df = properties_df.sort_values(by=['scraping_date'])

# %%
properties_df
# Out:
#                id scraping_date  agencyid  bedroomsnumber  buildingyear  \
# 669203  103007050    2023-09-26  139450.0             3.0        1970.0
# 656118  105802031    2023-09-26  235162.0             1.0        1975.0
# 656122  104049465    2023-09-26  184442.0             1.0        2005.0
# 656175  105766201    2023-09-26   17358.0             1.0        2002.0
# 656179  104641325    2023-09-26  375774.0             3.0        1970.0
# ...           ...           ...       ...             ...           ...
# 530585   99346912    2024-04-01  223338.0             2.0        1970.0
# 530586  103521532    2024-04-01  374571.0             2.0        1967.0
# 530592  100067196    2024-04-01   21926.0             3.0        1974.0
# 530086  104685793    2024-04-01   99234.0             2.0        1909.0
# 125216   93815526    2024-04-01  204925.0             2.0        2022.0
#
#          codcom    gsm  surface  latitude  longitude  ...      city  \
# 669203  99013.0  140.0      110   44.0007    12.6411  ...  Riccione
# 656118  37006.0   60.0       42   44.5228    11.2949  ...   Bologna
# 656122  37006.0   97.0       56   44.5224    11.2723  ...   Bologna
# 656175  46017.0   17.0       48   43.8420    10.4887  ...     Lucca
# 656179  46017.0   76.0      110   43.8423    10.4793  ...     Lucca
# ...         ...    ...      ...       ...        ...  ...       ...
# 530585  36023.0  508.0      160   44.6267    10.9078  ...    Modena
# 530586  36023.0  419.0       70   44.6375    10.9087  ...    Modena
# 530592  36023.0  549.0      135   44.6288    10.9141  ...    Modena
# 530086  17029.0  263.0      107   45.5316    10.2468  ...   Brescia
# 125216  58091.0  775.0       99   41.8410    12.4993  ...      Roma
#
#                      condition  energyclass     ga4heating  \
# 669203       Buono / Abitabile            G       Autonomo
# 656118  Ottimo / Ristrutturato            D       Autonomo
# 656122  Ottimo / Ristrutturato            E  Centralizzato
# 656175  Ottimo / Ristrutturato            E       Autonomo
# 656179       Buono / Abitabile            G  Centralizzato
# ...                        ...          ...            ...
# 530585  Ottimo / Ristrutturato            F       Autonomo
# 530586       Buono / Abitabile            G       Autonomo
# 530592       Buono / Abitabile            G  Centralizzato
# 530086  Ottimo / Ristrutturato            E  Centralizzato
# 125216  Nuovo / In costruzione           A3  Centralizzato
#
#                                                    garage  \
# 669203                     1 in box privato/box in garage
# 656118                      1 in parcheggio/garage comune
# 656122                      1 in parcheggio/garage comune
# 656175                      1 in parcheggio/garage comune
# 656179                      1 in parcheggio/garage comune
# ...                                                   ...
# 530585  1 in box privato/box in garage, 1 in parcheggi...
# 530586                     1 in box privato/box in garage
# 530592                     1 in box privato/box in garage
# 530086                      2 in parcheggio/garage comune
# 125216                      1 in parcheggio/garage comune
#
#                                               heatingtype  \
# 669203         autonomo, a radiatori, alimentato a metano
# 656118         autonomo, a radiatori, alimentato a metano
# 656122       centralizzato, a radiatori, alimentato a gas
# 656175                              autonomo, a radiatori
# 656179    centralizzato, a radiatori, alimentato a metano
# ...                                                   ...
# 530585            autonomo, a radiatori, alimentato a gas
# 530586            autonomo, a radiatori, alimentato a gas
# 530592    centralizzato, a radiatori, alimentato a metano
# 530086    centralizzato, a radiatori, alimentato a metano
# 125216  centralizzato, a pavimento, alimentato a pompa...
#
#                       pricerange rooms id_zona_omi     price
# 669203  200.001 - 300.000 &euro;     4     H274-D2  275000.0
# 656118  100.001 - 150.000 &euro;     2     A944-E5  143500.0
# 656122  150.001 - 200.000 &euro;     2     A944-E5  168000.0
# 656175  150.001 - 200.000 &euro;     3     E715-C1  155000.0
# 656179  100.001 - 150.000 &euro;    5+     E715-D1  149000.0
# ...                          ...   ...         ...       ...
# 530585  200.001 - 300.000 &euro;     5    F257-D28  298000.0
# 530586  150.001 - 200.000 &euro;     3    F257-D28  157000.0
# 530592  200.001 - 300.000 &euro;     5    F257-D28  290000.0
# 530086  300.001 - 500.000 &euro;     3     B157-C5  345000.0
# 125216  300.001 - 500.000 &euro;     3    H501-D34  428205.0
#
# [11232 rows x 26 columns]

# %%
omi_df = omi_df[[
    'id_zona_omi',
    'tipologia',
    'condizione',
    'compr_min',
    'compr_max',
    'zona_omi_type',
]]

# %%
omi_df
# Out:
#        id_zona_omi                     tipologia condizione  compr_min  \
# 0          A048-B1             Abitazioni civili    normale      812.0
# 1          A048-B1             Abitazioni civili     ottimo     1062.0
# 2          A048-B1             Abitazioni civili   scadente      539.0
# 3          A048-B1  Abitazioni di tipo economico    normale      650.0
# 4          A048-B1  Abitazioni di tipo economico     ottimo      892.0
# ...            ...                           ...        ...        ...
# 245119     M422-E1  Abitazioni di tipo economico     ottimo      787.0
# 245120     M422-E1  Abitazioni di tipo economico   scadente      328.0
# 245121     M422-E1               Ville e Villini    normale      680.0
# 245122     M422-E1               Ville e Villini     ottimo      920.0
# 245123     M422-E1               Ville e Villini   scadente      413.0
#
#         compr_max zona_omi_type
# 0          1165.0             B
# 1          1454.0             B
# 2           787.0             B
# 3           930.0             B
# 4          1192.0             B
# ...           ...           ...
# 245119      918.0             E
# 245120      412.0             E
# 245121      832.0             E
# 245122     1050.0             E
# 245123      517.0             E
#
# [240570 rows x 6 columns]

# %% [markdown]
# ## <span style="color:#ff5f27;"> 🪄 Creating Feature Groups </span>

# %%
fs = proj.get_feature_store()

# %%
# Get or create the 'properties' feature group
properties_fg = fs.get_or_create_feature_group(
    name='properties',
    version=4,                                                 # Breaking version
    description='Property Features and Corresponding Prices',
    online_enabled=True,                                       # Necessary for online inference
    primary_key=['id'],
    event_time='scraping_date',
)

# %%
# Insert data into feature group
properties_fg.insert(properties_df)
# Out:
# Uploading Dataframe: 100.00% |██████████| Rows 11232/11232 | Elapsed Time: 00:01 | Remaining Time: 00:00
# Launching job: properties_4_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1158295/jobs/named/properties_4_offline_fg_materialization/executions
# (Job('properties_4_offline_fg_materialization', 'SPARK'), None)

# %%
omi_fg = fs.get_or_create_feature_group(
    name='omi',
    version=2,
    description='OMI information',
    online_enabled=True,
    primary_key=['id_zona_omi'],
)

# %%
# Insert data into feature group
omi_fg.insert(omi_df)
# Out:
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1158295/fs/1148998/fg/1392972
# Uploading Dataframe: 100.00% |██████████| Rows 240570/240570 | Elapsed Time: 00:14 | Remaining Time: 00:00
# Launching job: omi_2_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1158295/jobs/named/omi_2_offline_fg_materialization/executions
# (Job('omi_2_offline_fg_materialization', 'SPARK'), None)
